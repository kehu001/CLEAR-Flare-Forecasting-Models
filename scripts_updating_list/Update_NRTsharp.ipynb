# %%
import sys
sys.path.append("D:\\0626_temp")

import process_sharp_keywords as psk

# %%
# Configuration parameters for SHARP data retrieval
start = "2010.05.01_00:00:00_TAI"
end = "2010.12.31_23:59:59_TAI"
lon = 70.0

# %%
process_sharp_keywords.sharp_download_main(start=start, end=end, lon=lon)
