# %%
import numpy as np
import pandas as pd
import torch
import os
import matplotlib.pyplot as plt
# Out:
# d:\Program Files\anaconda3\envs\torch126\Lib\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
import sys

from flare_preprocessing import *
from utilities import *

# %%
# %load_ext autoreload
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
working_dir = 'D:/2024_S1/ML_SEP_2402/Final_update/Open_Repo'
opr = opr_data_preprocessing(working_dir + "/data/v2_ftp_flares_1997_2024.csv")
sci = sci_data_preprocessing(working_dir + "/data/Sci_matched_with_assigned_ar_20100101_20241231.csv", opr)
# Out:
# Shape of the operation data: (25364, 9)
# Shape of the science-quality data: (32675, 26)
# d:\2024_S1\ML_SEP_2402\Final_update\Open_Repo\2607Revision\utilities.py:64: RuntimeWarning: divide by zero encountered in log10
#   return np.log10(intensity * 10 ** -8)

# %%
from New_SampleConstruction import *

# %%
# read the parquet file
import fastparquet
high_qual_sharp = pd.read_parquet('D:\\0626_temp\\processed_high-qual_near-center-70_no-nas_flares.parquet', engine='fastparquet')

# %%
# cut the time range from 2020
sci = sci[sci['peak_time'] >= '2020-01-01']
opr = opr[opr['peak_time'] >= '2020-01-01']
high_qual_sharp = high_qual_sharp[high_qual_sharp['T_REC'] >= '2020-01-01']

# %%
nowcast_sci_dft = New_SampleConstruction()
nowcast_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=0)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
nowcast_opr_dft = New_SampleConstruction()
nowcast_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=0)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
lead6_sci_dft = New_SampleConstruction()
lead6_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=6)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
lead6_opr_dft = New_SampleConstruction()
lead6_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=6)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
lead12_sci_dft = New_SampleConstruction()
lead12_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=12)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
lead12_opr_dft = New_SampleConstruction()
lead12_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=12)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
lead24_sci_dft = New_SampleConstruction()
lead24_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=24)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %%
lead24_opr_dft = New_SampleConstruction()
lead24_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=24)
# Out:
# Processing HARPNUM: np.int64(7401)
# Processing HARPNUM: np.int64(7402)
# Processing HARPNUM: np.int64(7403)
# Processing HARPNUM: np.int64(7405)
# Processing HARPNUM: np.int64(7406)
# Processing HARPNUM: np.int64(7408)
# Processing HARPNUM: np.int64(7410)
# Processing HARPNUM: np.int64(7411)
# Processing HARPNUM: np.int64(7412)
# Processing HARPNUM: np.int64(7413)
# Processing HARPNUM: np.int64(7414)
# Processing HARPNUM: np.int64(7415)
# Processing HARPNUM: np.int64(7416)
# Processing HARPNUM: np.int64(7417)
# Processing HARPNUM: np.int64(7418)
# Processing HARPNUM: np.int64(7419)
# Processing HARPNUM: np.int64(7420)
# Processing HARPNUM: np.int64(7422)
# Processing HARPNUM: np.int64(7424)
# Processing HARPNUM: np.int64(7425)
# Processing HARPNUM: np.int64(7426)
# Processing HARPNUM: np.int64(7427)
# Processing HARPNUM: np.int64(7428)
# Processing HARPNUM: np.int64(7429)
# Processing HARPNUM: np.int64(7430)
# Processing HARPNUM: np.int64(7431)
# Processing HARPNUM: np.int64(7432)
# ...

# %% [markdown]
# ## Results

# %% [markdown]
# ### LSTM + DEF

# %%
import importlib
from Gen_Results import GenMetrics_lstm

#importlib.reload(Gen_Results)

# %%
period_results = GenMetrics_lstm(
    model_name="nowcast_Task1_sci_dft",
    sample_obj=nowcast_sci_dft,
    model_dir="./LSTM_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-S-DEF-0.csv",
)
# Out:
# Threshold: 0.500[0.500,0.500]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 2365
# Bootstrap 1/30: nowcast_Task1_sci_dft0_0.5.pth, threshold=0.5
# Bootstrap 2/30: nowcast_Task1_sci_dft1_0.5.pth, threshold=0.5
# Bootstrap 3/30: nowcast_Task1_sci_dft2_0.5.pth, threshold=0.5
# Bootstrap 4/30: nowcast_Task1_sci_dft3_0.5.pth, threshold=0.5
# Bootstrap 5/30: nowcast_Task1_sci_dft4_0.5.pth, threshold=0.5
# Bootstrap 6/30: nowcast_Task1_sci_dft5_0.5.pth, threshold=0.5
# Bootstrap 7/30: nowcast_Task1_sci_dft6_0.5.pth, threshold=0.5
# Bootstrap 8/30: nowcast_Task1_sci_dft7_0.5.pth, threshold=0.5
# Bootstrap 9/30: nowcast_Task1_sci_dft8_0.5.pth, threshold=0.5
# Bootstrap 10/30: nowcast_Task1_sci_dft9_0.5.pth, threshold=0.5
# Bootstrap 11/30: nowcast_Task1_sci_dft10_0.5.pth, threshold=0.5
# Bootstrap 12/30: nowcast_Task1_sci_dft11_0.5.pth, threshold=0.5
# Bootstrap 13/30: nowcast_Task1_sci_dft12_0.5.pth, threshold=0.5
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="nowcast_Task2_sci_dft",
    sample_obj=nowcast_sci_dft,
    model_dir="./LSTM_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-S-DEF-0.csv",
)
# Out:
# Threshold: 0.480[0.480,0.480]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 3440
# Bootstrap 1/30: nowcast_Task2_sci_dft0_0.48.pth, threshold=0.48
# Bootstrap 2/30: nowcast_Task2_sci_dft1_0.48.pth, threshold=0.48
# Bootstrap 3/30: nowcast_Task2_sci_dft2_0.48.pth, threshold=0.48
# Bootstrap 4/30: nowcast_Task2_sci_dft3_0.48.pth, threshold=0.48
# Bootstrap 5/30: nowcast_Task2_sci_dft4_0.48.pth, threshold=0.48
# Bootstrap 6/30: nowcast_Task2_sci_dft5_0.48.pth, threshold=0.48
# Bootstrap 7/30: nowcast_Task2_sci_dft6_0.48.pth, threshold=0.48
# Bootstrap 8/30: nowcast_Task2_sci_dft7_0.48.pth, threshold=0.48
# Bootstrap 9/30: nowcast_Task2_sci_dft8_0.48.pth, threshold=0.48
# Bootstrap 10/30: nowcast_Task2_sci_dft9_0.48.pth, threshold=0.48
# Bootstrap 11/30: nowcast_Task2_sci_dft10_0.48.pth, threshold=0.48
# Bootstrap 12/30: nowcast_Task2_sci_dft11_0.48.pth, threshold=0.48
# Bootstrap 13/30: nowcast_Task2_sci_dft12_0.48.pth, threshold=0.48
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="nowcast_Task1_opr_dft",
    sample_obj=nowcast_sci_dft,
    model_dir="./LSTM_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-O-DEF-0.csv",
)
# Out:
# Threshold: 0.425[0.425,0.425]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 2365
# Bootstrap 1/30: nowcast_Task1_opr_dft0_0.42500000000000004.pth, threshold=0.425
# Bootstrap 2/30: nowcast_Task1_opr_dft1_0.42500000000000004.pth, threshold=0.425
# Bootstrap 3/30: nowcast_Task1_opr_dft2_0.42500000000000004.pth, threshold=0.425
# Bootstrap 4/30: nowcast_Task1_opr_dft3_0.42500000000000004.pth, threshold=0.425
# Bootstrap 5/30: nowcast_Task1_opr_dft4_0.42500000000000004.pth, threshold=0.425
# Bootstrap 6/30: nowcast_Task1_opr_dft5_0.42500000000000004.pth, threshold=0.425
# Bootstrap 7/30: nowcast_Task1_opr_dft6_0.42500000000000004.pth, threshold=0.425
# Bootstrap 8/30: nowcast_Task1_opr_dft7_0.42500000000000004.pth, threshold=0.425
# Bootstrap 9/30: nowcast_Task1_opr_dft8_0.42500000000000004.pth, threshold=0.425
# Bootstrap 10/30: nowcast_Task1_opr_dft9_0.42500000000000004.pth, threshold=0.425
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="nowcast_Task2_opr_dft",
    sample_obj=nowcast_sci_dft,
    model_dir="./LSTM_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-O-DEF-0.csv",
)
# Out:
# Threshold: 0.420[0.420,0.420]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 3440
# Bootstrap 1/30: nowcast_Task2_opr_dft0_0.42.pth, threshold=0.42
# Bootstrap 2/30: nowcast_Task2_opr_dft1_0.42.pth, threshold=0.42
# Bootstrap 3/30: nowcast_Task2_opr_dft2_0.42.pth, threshold=0.42
# Bootstrap 4/30: nowcast_Task2_opr_dft3_0.42.pth, threshold=0.42
# Bootstrap 5/30: nowcast_Task2_opr_dft4_0.42.pth, threshold=0.42
# Bootstrap 6/30: nowcast_Task2_opr_dft5_0.42.pth, threshold=0.42
# Bootstrap 7/30: nowcast_Task2_opr_dft6_0.42.pth, threshold=0.42
# Bootstrap 8/30: nowcast_Task2_opr_dft7_0.42.pth, threshold=0.42
# Bootstrap 9/30: nowcast_Task2_opr_dft8_0.42.pth, threshold=0.42
# Bootstrap 10/30: nowcast_Task2_opr_dft9_0.42.pth, threshold=0.42
# Bootstrap 11/30: nowcast_Task2_opr_dft10_0.42.pth, threshold=0.42
# Bootstrap 12/30: nowcast_Task2_opr_dft11_0.42.pth, threshold=0.42
# Bootstrap 13/30: nowcast_Task2_opr_dft12_0.42.pth, threshold=0.42
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead6_Task1_sci_dft",
    sample_obj=lead6_sci_dft,
    model_dir="./LSTM_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-S-DEF-6.csv",
)
# Out:
# Threshold: 0.445[0.445,0.445]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 2341
# Bootstrap 1/30: lead6_Task1_sci_dft0_0.44500000000000006.pth, threshold=0.445
# Bootstrap 2/30: lead6_Task1_sci_dft1_0.44500000000000006.pth, threshold=0.445
# Bootstrap 3/30: lead6_Task1_sci_dft2_0.44500000000000006.pth, threshold=0.445
# Bootstrap 4/30: lead6_Task1_sci_dft3_0.44500000000000006.pth, threshold=0.445
# Bootstrap 5/30: lead6_Task1_sci_dft4_0.44500000000000006.pth, threshold=0.445
# Bootstrap 6/30: lead6_Task1_sci_dft5_0.44500000000000006.pth, threshold=0.445
# Bootstrap 7/30: lead6_Task1_sci_dft6_0.44500000000000006.pth, threshold=0.445
# Bootstrap 8/30: lead6_Task1_sci_dft7_0.44500000000000006.pth, threshold=0.445
# Bootstrap 9/30: lead6_Task1_sci_dft8_0.44500000000000006.pth, threshold=0.445
# Bootstrap 10/30: lead6_Task1_sci_dft9_0.44500000000000006.pth, threshold=0.445
# Bootstrap 11/30: lead6_Task1_sci_dft10_0.44500000000000006.pth, threshold=0.445
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead6_Task2_sci_dft",
    sample_obj=lead6_sci_dft,
    model_dir="./LSTM_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-S-DEF-6.csv",
)
# Out:
# Threshold: 0.500[0.500,0.500]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 3401
# Bootstrap 1/30: lead6_Task2_sci_dft0_0.5.pth, threshold=0.5
# Bootstrap 2/30: lead6_Task2_sci_dft1_0.5.pth, threshold=0.5
# Bootstrap 3/30: lead6_Task2_sci_dft2_0.5.pth, threshold=0.5
# Bootstrap 4/30: lead6_Task2_sci_dft3_0.5.pth, threshold=0.5
# Bootstrap 5/30: lead6_Task2_sci_dft4_0.5.pth, threshold=0.5
# Bootstrap 6/30: lead6_Task2_sci_dft5_0.5.pth, threshold=0.5
# Bootstrap 7/30: lead6_Task2_sci_dft6_0.5.pth, threshold=0.5
# Bootstrap 8/30: lead6_Task2_sci_dft7_0.5.pth, threshold=0.5
# Bootstrap 9/30: lead6_Task2_sci_dft8_0.5.pth, threshold=0.5
# Bootstrap 10/30: lead6_Task2_sci_dft9_0.5.pth, threshold=0.5
# Bootstrap 11/30: lead6_Task2_sci_dft10_0.5.pth, threshold=0.5
# Bootstrap 12/30: lead6_Task2_sci_dft11_0.5.pth, threshold=0.5
# Bootstrap 13/30: lead6_Task2_sci_dft12_0.5.pth, threshold=0.5
# Bootstrap 14/30: lead6_Task2_sci_dft13_0.5.pth, threshold=0.5
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead6_Task1_opr_dft",
    sample_obj=lead6_opr_dft,
    model_dir="./LSTM_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-O-DEF-6.csv",
)
# Out:
# Threshold: 0.450[0.450,0.450]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 138, Negative: 2394
# Bootstrap 1/30: lead6_Task1_opr_dft0_0.45.pth, threshold=0.45
# Bootstrap 2/30: lead6_Task1_opr_dft1_0.45.pth, threshold=0.45
# Bootstrap 3/30: lead6_Task1_opr_dft2_0.45.pth, threshold=0.45
# Bootstrap 4/30: lead6_Task1_opr_dft3_0.45.pth, threshold=0.45
# Bootstrap 5/30: lead6_Task1_opr_dft4_0.45.pth, threshold=0.45
# Bootstrap 6/30: lead6_Task1_opr_dft5_0.45.pth, threshold=0.45
# Bootstrap 7/30: lead6_Task1_opr_dft6_0.45.pth, threshold=0.45
# Bootstrap 8/30: lead6_Task1_opr_dft7_0.45.pth, threshold=0.45
# Bootstrap 9/30: lead6_Task1_opr_dft8_0.45.pth, threshold=0.45
# Bootstrap 10/30: lead6_Task1_opr_dft9_0.45.pth, threshold=0.45
# Bootstrap 11/30: lead6_Task1_opr_dft10_0.45.pth, threshold=0.45
# Bootstrap 12/30: lead6_Task1_opr_dft11_0.45.pth, threshold=0.45
# Bootstrap 13/30: lead6_Task1_opr_dft12_0.45.pth, threshold=0.45
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead6_Task2_opr_dft",
    sample_obj=lead6_opr_dft,
    model_dir="./LSTM_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-O-DEF-6.csv",
)
# Out:
# Threshold: 0.500[0.500,0.500]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 138, Negative: 3634
# Bootstrap 1/30: lead6_Task2_opr_dft0_0.5.pth, threshold=0.5
# Bootstrap 2/30: lead6_Task2_opr_dft1_0.5.pth, threshold=0.5
# Bootstrap 3/30: lead6_Task2_opr_dft2_0.5.pth, threshold=0.5
# Bootstrap 4/30: lead6_Task2_opr_dft3_0.5.pth, threshold=0.5
# Bootstrap 5/30: lead6_Task2_opr_dft4_0.5.pth, threshold=0.5
# Bootstrap 6/30: lead6_Task2_opr_dft5_0.5.pth, threshold=0.5
# Bootstrap 7/30: lead6_Task2_opr_dft6_0.5.pth, threshold=0.5
# Bootstrap 8/30: lead6_Task2_opr_dft7_0.5.pth, threshold=0.5
# Bootstrap 9/30: lead6_Task2_opr_dft8_0.5.pth, threshold=0.5
# Bootstrap 10/30: lead6_Task2_opr_dft9_0.5.pth, threshold=0.5
# Bootstrap 11/30: lead6_Task2_opr_dft10_0.5.pth, threshold=0.5
# Bootstrap 12/30: lead6_Task2_opr_dft11_0.5.pth, threshold=0.5
# Bootstrap 13/30: lead6_Task2_opr_dft12_0.5.pth, threshold=0.5
# Bootstrap 14/30: lead6_Task2_opr_dft13_0.5.pth, threshold=0.5
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead12_Task1_sci_dft",
    sample_obj=lead12_sci_dft,
    model_dir="./LSTM_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-S-DEF-12.csv",
)
# Out:
# Threshold: 0.570[0.570,0.570]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 2305
# Bootstrap 1/30: lead12_Task1_sci_dft0_0.57.pth, threshold=0.57
# Bootstrap 2/30: lead12_Task1_sci_dft1_0.57.pth, threshold=0.57
# Bootstrap 3/30: lead12_Task1_sci_dft2_0.57.pth, threshold=0.57
# Bootstrap 4/30: lead12_Task1_sci_dft3_0.57.pth, threshold=0.57
# Bootstrap 5/30: lead12_Task1_sci_dft4_0.57.pth, threshold=0.57
# Bootstrap 6/30: lead12_Task1_sci_dft5_0.57.pth, threshold=0.57
# Bootstrap 7/30: lead12_Task1_sci_dft6_0.57.pth, threshold=0.57
# Bootstrap 8/30: lead12_Task1_sci_dft7_0.57.pth, threshold=0.57
# Bootstrap 9/30: lead12_Task1_sci_dft8_0.57.pth, threshold=0.57
# Bootstrap 10/30: lead12_Task1_sci_dft9_0.57.pth, threshold=0.57
# Bootstrap 11/30: lead12_Task1_sci_dft10_0.57.pth, threshold=0.57
# Bootstrap 12/30: lead12_Task1_sci_dft11_0.57.pth, threshold=0.57
# Bootstrap 13/30: lead12_Task1_sci_dft12_0.57.pth, threshold=0.57
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead12_Task2_sci_dft",
    sample_obj=lead12_sci_dft,
    model_dir="./LSTM_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-S-DEF-12.csv",
)
# Out:
# Threshold: 0.490[0.490,0.490]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 3346
# Bootstrap 1/30: lead12_Task2_sci_dft0_0.49.pth, threshold=0.49
# Bootstrap 2/30: lead12_Task2_sci_dft1_0.49.pth, threshold=0.49
# Bootstrap 3/30: lead12_Task2_sci_dft2_0.49.pth, threshold=0.49
# Bootstrap 4/30: lead12_Task2_sci_dft3_0.49.pth, threshold=0.49
# Bootstrap 5/30: lead12_Task2_sci_dft4_0.49.pth, threshold=0.49
# Bootstrap 6/30: lead12_Task2_sci_dft5_0.49.pth, threshold=0.49
# Bootstrap 7/30: lead12_Task2_sci_dft6_0.49.pth, threshold=0.49
# Bootstrap 8/30: lead12_Task2_sci_dft7_0.49.pth, threshold=0.49
# Bootstrap 9/30: lead12_Task2_sci_dft8_0.49.pth, threshold=0.49
# Bootstrap 10/30: lead12_Task2_sci_dft9_0.49.pth, threshold=0.49
# Bootstrap 11/30: lead12_Task2_sci_dft10_0.49.pth, threshold=0.49
# Bootstrap 12/30: lead12_Task2_sci_dft11_0.49.pth, threshold=0.49
# Bootstrap 13/30: lead12_Task2_sci_dft12_0.49.pth, threshold=0.49
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead12_Task1_opr_dft",
    sample_obj=lead12_opr_dft,
    model_dir="./LSTM_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-O-DEF-12.csv",
)
# Out:
# Threshold: 0.453[0.453,0.453]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 139, Negative: 2351
# Bootstrap 1/30: lead12_Task1_opr_dft0_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 2/30: lead12_Task1_opr_dft1_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 3/30: lead12_Task1_opr_dft2_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 4/30: lead12_Task1_opr_dft3_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 5/30: lead12_Task1_opr_dft4_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 6/30: lead12_Task1_opr_dft5_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 7/30: lead12_Task1_opr_dft6_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 8/30: lead12_Task1_opr_dft7_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 9/30: lead12_Task1_opr_dft8_0.45333333333333337.pth, threshold=0.453333
# Bootstrap 10/30: lead12_Task1_opr_dft9_0.45333333333333337.pth, threshold=0.453333
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead12_Task2_opr_dft",
    sample_obj=lead12_opr_dft,
    model_dir="./LSTM_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-O-DEF-12.csv",
)
# Out:
# Threshold: 0.440[0.440,0.440]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 139, Negative: 3580
# Bootstrap 1/30: lead12_Task2_opr_dft0_0.44.pth, threshold=0.44
# Bootstrap 2/30: lead12_Task2_opr_dft1_0.44.pth, threshold=0.44
# Bootstrap 3/30: lead12_Task2_opr_dft2_0.44.pth, threshold=0.44
# Bootstrap 4/30: lead12_Task2_opr_dft3_0.44.pth, threshold=0.44
# Bootstrap 5/30: lead12_Task2_opr_dft4_0.44.pth, threshold=0.44
# Bootstrap 6/30: lead12_Task2_opr_dft5_0.44.pth, threshold=0.44
# Bootstrap 7/30: lead12_Task2_opr_dft6_0.44.pth, threshold=0.44
# Bootstrap 8/30: lead12_Task2_opr_dft7_0.44.pth, threshold=0.44
# Bootstrap 9/30: lead12_Task2_opr_dft8_0.44.pth, threshold=0.44
# Bootstrap 10/30: lead12_Task2_opr_dft9_0.44.pth, threshold=0.44
# Bootstrap 11/30: lead12_Task2_opr_dft10_0.44.pth, threshold=0.44
# Bootstrap 12/30: lead12_Task2_opr_dft11_0.44.pth, threshold=0.44
# Bootstrap 13/30: lead12_Task2_opr_dft12_0.44.pth, threshold=0.44
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead24_Task1_sci_dft",
    sample_obj=lead24_sci_dft,
    model_dir="./LSTM_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-S-DEF-24.csv",
)
# Out:
# Threshold: 0.533[0.533,0.533]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 2168
# Bootstrap 1/30: lead24_Task1_sci_dft0_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 2/30: lead24_Task1_sci_dft1_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 3/30: lead24_Task1_sci_dft2_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 4/30: lead24_Task1_sci_dft3_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 5/30: lead24_Task1_sci_dft4_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 6/30: lead24_Task1_sci_dft5_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 7/30: lead24_Task1_sci_dft6_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 8/30: lead24_Task1_sci_dft7_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 9/30: lead24_Task1_sci_dft8_0.5333333333333333.pth, threshold=0.533333
# Bootstrap 10/30: lead24_Task1_sci_dft9_0.5333333333333333.pth, threshold=0.533333
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead24_Task2_sci_dft",
    sample_obj=lead24_sci_dft,
    model_dir="./LSTM_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-S-DEF-24.csv",
)
# Out:
# Threshold: 0.480[0.480,0.480]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 3165
# Bootstrap 1/30: lead24_Task2_sci_dft0_0.48.pth, threshold=0.48
# Bootstrap 2/30: lead24_Task2_sci_dft1_0.48.pth, threshold=0.48
# Bootstrap 3/30: lead24_Task2_sci_dft2_0.48.pth, threshold=0.48
# Bootstrap 4/30: lead24_Task2_sci_dft3_0.48.pth, threshold=0.48
# Bootstrap 5/30: lead24_Task2_sci_dft4_0.48.pth, threshold=0.48
# Bootstrap 6/30: lead24_Task2_sci_dft5_0.48.pth, threshold=0.48
# Bootstrap 7/30: lead24_Task2_sci_dft6_0.48.pth, threshold=0.48
# Bootstrap 8/30: lead24_Task2_sci_dft7_0.48.pth, threshold=0.48
# Bootstrap 9/30: lead24_Task2_sci_dft8_0.48.pth, threshold=0.48
# Bootstrap 10/30: lead24_Task2_sci_dft9_0.48.pth, threshold=0.48
# Bootstrap 11/30: lead24_Task2_sci_dft10_0.48.pth, threshold=0.48
# Bootstrap 12/30: lead24_Task2_sci_dft11_0.48.pth, threshold=0.48
# Bootstrap 13/30: lead24_Task2_sci_dft12_0.48.pth, threshold=0.48
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead24_Task1_opr_dft",
    sample_obj=lead24_opr_dft,
    model_dir="./LSTM_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_LSTM-O-DEF-24.csv",
)
# Out:
# Threshold: 0.543[0.543,0.543]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 140, Negative: 2236
# Bootstrap 1/30: lead24_Task1_opr_dft0_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 2/30: lead24_Task1_opr_dft1_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 3/30: lead24_Task1_opr_dft2_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 4/30: lead24_Task1_opr_dft3_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 5/30: lead24_Task1_opr_dft4_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 6/30: lead24_Task1_opr_dft5_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 7/30: lead24_Task1_opr_dft6_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 8/30: lead24_Task1_opr_dft7_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 9/30: lead24_Task1_opr_dft8_0.5433333333333334.pth, threshold=0.543333
# Bootstrap 10/30: lead24_Task1_opr_dft9_0.5433333333333334.pth, threshold=0.543333
# ...

# %%
period_results = GenMetrics_lstm(
    model_name="lead24_Task2_opr_dft",
    sample_obj=lead24_opr_dft,
    model_dir="./LSTM_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_LSTM-O-DEF-24.csv",
)
# Out:
# Threshold: 0.460[0.460,0.460]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 140, Negative: 3422
# Bootstrap 1/30: lead24_Task2_opr_dft0_0.46.pth, threshold=0.46
# Bootstrap 2/30: lead24_Task2_opr_dft1_0.46.pth, threshold=0.46
# Bootstrap 3/30: lead24_Task2_opr_dft2_0.46.pth, threshold=0.46
# Bootstrap 4/30: lead24_Task2_opr_dft3_0.46.pth, threshold=0.46
# Bootstrap 5/30: lead24_Task2_opr_dft4_0.46.pth, threshold=0.46
# Bootstrap 6/30: lead24_Task2_opr_dft5_0.46.pth, threshold=0.46
# Bootstrap 7/30: lead24_Task2_opr_dft6_0.46.pth, threshold=0.46
# Bootstrap 8/30: lead24_Task2_opr_dft7_0.46.pth, threshold=0.46
# Bootstrap 9/30: lead24_Task2_opr_dft8_0.46.pth, threshold=0.46
# Bootstrap 10/30: lead24_Task2_opr_dft9_0.46.pth, threshold=0.46
# Bootstrap 11/30: lead24_Task2_opr_dft10_0.46.pth, threshold=0.46
# Bootstrap 12/30: lead24_Task2_opr_dft11_0.46.pth, threshold=0.46
# Bootstrap 13/30: lead24_Task2_opr_dft12_0.46.pth, threshold=0.46
# ...

# %% [markdown]
# ### Logreg + def

# %%
from Gen_Results import GenMetrics_logreg

#importlib.reload(Gen_Results)

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_nowcast_Task1_sci_dft",
    sample_obj=nowcast_sci_dft,
    model_dir="./Logreg_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-S-DEF-0.csv",
)
# Out:
# Threshold: 0.450[0.450,0.450]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 2365
# Bootstrap 1/30: logistic_nowcast_Task1_sci_dft0_0.45.pth, threshold=0.45
# Bootstrap 2/30: logistic_nowcast_Task1_sci_dft1_0.45.pth, threshold=0.45
# Bootstrap 3/30: logistic_nowcast_Task1_sci_dft2_0.45.pth, threshold=0.45
# Bootstrap 4/30: logistic_nowcast_Task1_sci_dft3_0.45.pth, threshold=0.45
# Bootstrap 5/30: logistic_nowcast_Task1_sci_dft4_0.45.pth, threshold=0.45
# Bootstrap 6/30: logistic_nowcast_Task1_sci_dft5_0.45.pth, threshold=0.45
# Bootstrap 7/30: logistic_nowcast_Task1_sci_dft6_0.45.pth, threshold=0.45
# Bootstrap 8/30: logistic_nowcast_Task1_sci_dft7_0.45.pth, threshold=0.45
# Bootstrap 9/30: logistic_nowcast_Task1_sci_dft8_0.45.pth, threshold=0.45
# Bootstrap 10/30: logistic_nowcast_Task1_sci_dft9_0.45.pth, threshold=0.45
# Bootstrap 11/30: logistic_nowcast_Task1_sci_dft10_0.45.pth, threshold=0.45
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_nowcast_Task2_sci_dft",
    sample_obj=nowcast_sci_dft,
    model_dir="./Logreg_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-S-DEF-0.csv",
)
# Out:
# Threshold: 0.450[0.450,0.450]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 3440
# Bootstrap 1/30: logistic_nowcast_Task2_sci_dft0_0.45.pth, threshold=0.45
# Bootstrap 2/30: logistic_nowcast_Task2_sci_dft1_0.45.pth, threshold=0.45
# Bootstrap 3/30: logistic_nowcast_Task2_sci_dft2_0.45.pth, threshold=0.45
# Bootstrap 4/30: logistic_nowcast_Task2_sci_dft3_0.45.pth, threshold=0.45
# Bootstrap 5/30: logistic_nowcast_Task2_sci_dft4_0.45.pth, threshold=0.45
# Bootstrap 6/30: logistic_nowcast_Task2_sci_dft5_0.45.pth, threshold=0.45
# Bootstrap 7/30: logistic_nowcast_Task2_sci_dft6_0.45.pth, threshold=0.45
# Bootstrap 8/30: logistic_nowcast_Task2_sci_dft7_0.45.pth, threshold=0.45
# Bootstrap 9/30: logistic_nowcast_Task2_sci_dft8_0.45.pth, threshold=0.45
# Bootstrap 10/30: logistic_nowcast_Task2_sci_dft9_0.45.pth, threshold=0.45
# Bootstrap 11/30: logistic_nowcast_Task2_sci_dft10_0.45.pth, threshold=0.45
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_nowcast_Task1_opr_dft",
    sample_obj=nowcast_opr_dft,
    model_dir="./Logreg_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-O-DEF-0.csv",
)
# Out:
# Threshold: 0.450[0.450,0.450]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 138, Negative: 2446
# Bootstrap 1/30: logistic_nowcast_Task1_opr_dft0_0.45.pth, threshold=0.45
# Bootstrap 2/30: logistic_nowcast_Task1_opr_dft1_0.45.pth, threshold=0.45
# Bootstrap 3/30: logistic_nowcast_Task1_opr_dft2_0.45.pth, threshold=0.45
# Bootstrap 4/30: logistic_nowcast_Task1_opr_dft3_0.45.pth, threshold=0.45
# Bootstrap 5/30: logistic_nowcast_Task1_opr_dft4_0.45.pth, threshold=0.45
# Bootstrap 6/30: logistic_nowcast_Task1_opr_dft5_0.45.pth, threshold=0.45
# Bootstrap 7/30: logistic_nowcast_Task1_opr_dft6_0.45.pth, threshold=0.45
# Bootstrap 8/30: logistic_nowcast_Task1_opr_dft7_0.45.pth, threshold=0.45
# Bootstrap 9/30: logistic_nowcast_Task1_opr_dft8_0.45.pth, threshold=0.45
# Bootstrap 10/30: logistic_nowcast_Task1_opr_dft9_0.45.pth, threshold=0.45
# Bootstrap 11/30: logistic_nowcast_Task1_opr_dft10_0.45.pth, threshold=0.45
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_nowcast_Task2_opr_dft",
    sample_obj=nowcast_opr_dft,
    model_dir="./Logreg_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-O-DEF-0.csv",
)
# Out:
# Threshold: 0.430[0.430,0.430]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 138, Negative: 3692
# Bootstrap 1/30: logistic_nowcast_Task2_opr_dft0_0.43.pth, threshold=0.43
# Bootstrap 2/30: logistic_nowcast_Task2_opr_dft1_0.43.pth, threshold=0.43
# Bootstrap 3/30: logistic_nowcast_Task2_opr_dft2_0.43.pth, threshold=0.43
# Bootstrap 4/30: logistic_nowcast_Task2_opr_dft3_0.43.pth, threshold=0.43
# Bootstrap 5/30: logistic_nowcast_Task2_opr_dft4_0.43.pth, threshold=0.43
# Bootstrap 6/30: logistic_nowcast_Task2_opr_dft5_0.43.pth, threshold=0.43
# Bootstrap 7/30: logistic_nowcast_Task2_opr_dft6_0.43.pth, threshold=0.43
# Bootstrap 8/30: logistic_nowcast_Task2_opr_dft7_0.43.pth, threshold=0.43
# Bootstrap 9/30: logistic_nowcast_Task2_opr_dft8_0.43.pth, threshold=0.43
# Bootstrap 10/30: logistic_nowcast_Task2_opr_dft9_0.43.pth, threshold=0.43
# Bootstrap 11/30: logistic_nowcast_Task2_opr_dft10_0.43.pth, threshold=0.43
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead6_Task1_sci_dft",
    sample_obj=lead6_sci_dft,
    model_dir="./Logreg_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-S-DEF-6.csv",
)
# Out:
# Threshold: 0.530[0.530,0.530]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 2341
# Bootstrap 1/30: logistic_lead6_Task1_sci_dft0_0.53.pth, threshold=0.53
# Bootstrap 2/30: logistic_lead6_Task1_sci_dft1_0.53.pth, threshold=0.53
# Bootstrap 3/30: logistic_lead6_Task1_sci_dft2_0.53.pth, threshold=0.53
# Bootstrap 4/30: logistic_lead6_Task1_sci_dft3_0.53.pth, threshold=0.53
# Bootstrap 5/30: logistic_lead6_Task1_sci_dft4_0.53.pth, threshold=0.53
# Bootstrap 6/30: logistic_lead6_Task1_sci_dft5_0.53.pth, threshold=0.53
# Bootstrap 7/30: logistic_lead6_Task1_sci_dft6_0.53.pth, threshold=0.53
# Bootstrap 8/30: logistic_lead6_Task1_sci_dft7_0.53.pth, threshold=0.53
# Bootstrap 9/30: logistic_lead6_Task1_sci_dft8_0.53.pth, threshold=0.53
# Bootstrap 10/30: logistic_lead6_Task1_sci_dft9_0.53.pth, threshold=0.53
# Bootstrap 11/30: logistic_lead6_Task1_sci_dft10_0.53.pth, threshold=0.53
# Bootstrap 12/30: logistic_lead6_Task1_sci_dft11_0.53.pth, threshold=0.53
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead6_Task2_sci_dft",
    sample_obj=lead6_sci_dft,
    model_dir="./Logreg_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-S-DEF-6.csv",
)
# Out:
# Threshold: 0.450[0.450,0.450]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 92, Negative: 3401
# Bootstrap 1/30: logistic_lead6_Task2_sci_dft0_0.45.pth, threshold=0.45
# Bootstrap 2/30: logistic_lead6_Task2_sci_dft1_0.45.pth, threshold=0.45
# Bootstrap 3/30: logistic_lead6_Task2_sci_dft2_0.45.pth, threshold=0.45
# Bootstrap 4/30: logistic_lead6_Task2_sci_dft3_0.45.pth, threshold=0.45
# Bootstrap 5/30: logistic_lead6_Task2_sci_dft4_0.45.pth, threshold=0.45
# Bootstrap 6/30: logistic_lead6_Task2_sci_dft5_0.45.pth, threshold=0.45
# Bootstrap 7/30: logistic_lead6_Task2_sci_dft6_0.45.pth, threshold=0.45
# Bootstrap 8/30: logistic_lead6_Task2_sci_dft7_0.45.pth, threshold=0.45
# Bootstrap 9/30: logistic_lead6_Task2_sci_dft8_0.45.pth, threshold=0.45
# Bootstrap 10/30: logistic_lead6_Task2_sci_dft9_0.45.pth, threshold=0.45
# Bootstrap 11/30: logistic_lead6_Task2_sci_dft10_0.45.pth, threshold=0.45
# Bootstrap 12/30: logistic_lead6_Task2_sci_dft11_0.45.pth, threshold=0.45
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead6_Task1_opr_dft",
    sample_obj=lead6_opr_dft,
    model_dir="./Logreg_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-O-DEF-6.csv",
)
# Out:
# Threshold: 0.490[0.490,0.490]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 138, Negative: 2394
# Bootstrap 1/30: logistic_lead6_Task1_opr_dft0_0.49.pth, threshold=0.49
# Bootstrap 2/30: logistic_lead6_Task1_opr_dft1_0.49.pth, threshold=0.49
# Bootstrap 3/30: logistic_lead6_Task1_opr_dft2_0.49.pth, threshold=0.49
# Bootstrap 4/30: logistic_lead6_Task1_opr_dft3_0.49.pth, threshold=0.49
# Bootstrap 5/30: logistic_lead6_Task1_opr_dft4_0.49.pth, threshold=0.49
# Bootstrap 6/30: logistic_lead6_Task1_opr_dft5_0.49.pth, threshold=0.49
# Bootstrap 7/30: logistic_lead6_Task1_opr_dft6_0.49.pth, threshold=0.49
# Bootstrap 8/30: logistic_lead6_Task1_opr_dft7_0.49.pth, threshold=0.49
# Bootstrap 9/30: logistic_lead6_Task1_opr_dft8_0.49.pth, threshold=0.49
# Bootstrap 10/30: logistic_lead6_Task1_opr_dft9_0.49.pth, threshold=0.49
# Bootstrap 11/30: logistic_lead6_Task1_opr_dft10_0.49.pth, threshold=0.49
# Bootstrap 12/30: logistic_lead6_Task1_opr_dft11_0.49.pth, threshold=0.49
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead6_Task2_opr_dft",
    sample_obj=lead6_opr_dft,
    model_dir="./Logreg_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-O-DEF-6.csv",
)
# Out:
# Threshold: 0.410[0.410,0.410]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 138, Negative: 3634
# Bootstrap 1/30: logistic_lead6_Task2_opr_dft0_0.41.pth, threshold=0.41
# Bootstrap 2/30: logistic_lead6_Task2_opr_dft1_0.41.pth, threshold=0.41
# Bootstrap 3/30: logistic_lead6_Task2_opr_dft2_0.41.pth, threshold=0.41
# Bootstrap 4/30: logistic_lead6_Task2_opr_dft3_0.41.pth, threshold=0.41
# Bootstrap 5/30: logistic_lead6_Task2_opr_dft4_0.41.pth, threshold=0.41
# Bootstrap 6/30: logistic_lead6_Task2_opr_dft5_0.41.pth, threshold=0.41
# Bootstrap 7/30: logistic_lead6_Task2_opr_dft6_0.41.pth, threshold=0.41
# Bootstrap 8/30: logistic_lead6_Task2_opr_dft7_0.41.pth, threshold=0.41
# Bootstrap 9/30: logistic_lead6_Task2_opr_dft8_0.41.pth, threshold=0.41
# Bootstrap 10/30: logistic_lead6_Task2_opr_dft9_0.41.pth, threshold=0.41
# Bootstrap 11/30: logistic_lead6_Task2_opr_dft10_0.41.pth, threshold=0.41
# Bootstrap 12/30: logistic_lead6_Task2_opr_dft11_0.41.pth, threshold=0.41
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead12_Task1_sci_dft",
    sample_obj=lead12_sci_dft,
    model_dir="./Logreg_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-S-DEF-12.csv",
)
# Out:
# Threshold: 0.540[0.540,0.540]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 2305
# Bootstrap 1/30: logistic_lead12_Task1_sci_dft0_0.54.pth, threshold=0.54
# Bootstrap 2/30: logistic_lead12_Task1_sci_dft1_0.54.pth, threshold=0.54
# Bootstrap 3/30: logistic_lead12_Task1_sci_dft2_0.54.pth, threshold=0.54
# Bootstrap 4/30: logistic_lead12_Task1_sci_dft3_0.54.pth, threshold=0.54
# Bootstrap 5/30: logistic_lead12_Task1_sci_dft4_0.54.pth, threshold=0.54
# Bootstrap 6/30: logistic_lead12_Task1_sci_dft5_0.54.pth, threshold=0.54
# Bootstrap 7/30: logistic_lead12_Task1_sci_dft6_0.54.pth, threshold=0.54
# Bootstrap 8/30: logistic_lead12_Task1_sci_dft7_0.54.pth, threshold=0.54
# Bootstrap 9/30: logistic_lead12_Task1_sci_dft8_0.54.pth, threshold=0.54
# Bootstrap 10/30: logistic_lead12_Task1_sci_dft9_0.54.pth, threshold=0.54
# Bootstrap 11/30: logistic_lead12_Task1_sci_dft10_0.54.pth, threshold=0.54
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead12_Task2_sci_dft",
    sample_obj=lead12_sci_dft,
    model_dir="./Logreg_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-S-DEF-12.csv",
)
# Out:
# Threshold: 0.470[0.470,0.470]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 3346
# Bootstrap 1/30: logistic_lead12_Task2_sci_dft0_0.47.pth, threshold=0.47
# Bootstrap 2/30: logistic_lead12_Task2_sci_dft1_0.47.pth, threshold=0.47
# Bootstrap 3/30: logistic_lead12_Task2_sci_dft2_0.47.pth, threshold=0.47
# Bootstrap 4/30: logistic_lead12_Task2_sci_dft3_0.47.pth, threshold=0.47
# Bootstrap 5/30: logistic_lead12_Task2_sci_dft4_0.47.pth, threshold=0.47
# Bootstrap 6/30: logistic_lead12_Task2_sci_dft5_0.47.pth, threshold=0.47
# Bootstrap 7/30: logistic_lead12_Task2_sci_dft6_0.47.pth, threshold=0.47
# Bootstrap 8/30: logistic_lead12_Task2_sci_dft7_0.47.pth, threshold=0.47
# Bootstrap 9/30: logistic_lead12_Task2_sci_dft8_0.47.pth, threshold=0.47
# Bootstrap 10/30: logistic_lead12_Task2_sci_dft9_0.47.pth, threshold=0.47
# Bootstrap 11/30: logistic_lead12_Task2_sci_dft10_0.47.pth, threshold=0.47
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead12_Task1_opr_dft",
    sample_obj=lead12_opr_dft,
    model_dir="./Logreg_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-O-DEF-12.csv",
)
# Out:
# Threshold: 0.460[0.460,0.460]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 139, Negative: 2351
# Bootstrap 1/30: logistic_lead12_Task1_opr_dft0_0.46.pth, threshold=0.46
# Bootstrap 2/30: logistic_lead12_Task1_opr_dft1_0.46.pth, threshold=0.46
# Bootstrap 3/30: logistic_lead12_Task1_opr_dft2_0.46.pth, threshold=0.46
# Bootstrap 4/30: logistic_lead12_Task1_opr_dft3_0.46.pth, threshold=0.46
# Bootstrap 5/30: logistic_lead12_Task1_opr_dft4_0.46.pth, threshold=0.46
# Bootstrap 6/30: logistic_lead12_Task1_opr_dft5_0.46.pth, threshold=0.46
# Bootstrap 7/30: logistic_lead12_Task1_opr_dft6_0.46.pth, threshold=0.46
# Bootstrap 8/30: logistic_lead12_Task1_opr_dft7_0.46.pth, threshold=0.46
# Bootstrap 9/30: logistic_lead12_Task1_opr_dft8_0.46.pth, threshold=0.46
# Bootstrap 10/30: logistic_lead12_Task1_opr_dft9_0.46.pth, threshold=0.46
# Bootstrap 11/30: logistic_lead12_Task1_opr_dft10_0.46.pth, threshold=0.46
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead12_Task2_opr_dft",
    sample_obj=lead12_opr_dft,
    model_dir="./Logreg_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-O-DEF-12.csv",
)
# Out:
# Threshold: 0.430[0.430,0.430]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 139, Negative: 3580
# Bootstrap 1/30: logistic_lead12_Task2_opr_dft0_0.43.pth, threshold=0.43
# Bootstrap 2/30: logistic_lead12_Task2_opr_dft1_0.43.pth, threshold=0.43
# Bootstrap 3/30: logistic_lead12_Task2_opr_dft2_0.43.pth, threshold=0.43
# Bootstrap 4/30: logistic_lead12_Task2_opr_dft3_0.43.pth, threshold=0.43
# Bootstrap 5/30: logistic_lead12_Task2_opr_dft4_0.43.pth, threshold=0.43
# Bootstrap 6/30: logistic_lead12_Task2_opr_dft5_0.43.pth, threshold=0.43
# Bootstrap 7/30: logistic_lead12_Task2_opr_dft6_0.43.pth, threshold=0.43
# Bootstrap 8/30: logistic_lead12_Task2_opr_dft7_0.43.pth, threshold=0.43
# Bootstrap 9/30: logistic_lead12_Task2_opr_dft8_0.43.pth, threshold=0.43
# Bootstrap 10/30: logistic_lead12_Task2_opr_dft9_0.43.pth, threshold=0.43
# Bootstrap 11/30: logistic_lead12_Task2_opr_dft10_0.43.pth, threshold=0.43
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead24_Task1_sci_dft",
    sample_obj=lead24_sci_dft,
    model_dir="./Logreg_models/Task1_sci_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-S-DEF-24.csv",
)
# Out:
# Threshold: 0.490[0.490,0.490]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 2168
# Bootstrap 1/30: logistic_lead24_Task1_sci_dft0_0.49.pth, threshold=0.49
# Bootstrap 2/30: logistic_lead24_Task1_sci_dft1_0.49.pth, threshold=0.49
# Bootstrap 3/30: logistic_lead24_Task1_sci_dft2_0.49.pth, threshold=0.49
# Bootstrap 4/30: logistic_lead24_Task1_sci_dft3_0.49.pth, threshold=0.49
# Bootstrap 5/30: logistic_lead24_Task1_sci_dft4_0.49.pth, threshold=0.49
# Bootstrap 6/30: logistic_lead24_Task1_sci_dft5_0.49.pth, threshold=0.49
# Bootstrap 7/30: logistic_lead24_Task1_sci_dft6_0.49.pth, threshold=0.49
# Bootstrap 8/30: logistic_lead24_Task1_sci_dft7_0.49.pth, threshold=0.49
# Bootstrap 9/30: logistic_lead24_Task1_sci_dft8_0.49.pth, threshold=0.49
# Bootstrap 10/30: logistic_lead24_Task1_sci_dft9_0.49.pth, threshold=0.49
# Bootstrap 11/30: logistic_lead24_Task1_sci_dft10_0.49.pth, threshold=0.49
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead24_Task2_sci_dft",
    sample_obj=lead24_sci_dft,
    model_dir="./Logreg_models/Task2_sci_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-S-DEF-24.csv",
)
# Out:
# Threshold: 0.500[0.500,0.500]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 93, Negative: 3165
# Bootstrap 1/30: logistic_lead24_Task2_sci_dft0_0.5.pth, threshold=0.5
# Bootstrap 2/30: logistic_lead24_Task2_sci_dft1_0.5.pth, threshold=0.5
# Bootstrap 3/30: logistic_lead24_Task2_sci_dft2_0.5.pth, threshold=0.5
# Bootstrap 4/30: logistic_lead24_Task2_sci_dft3_0.5.pth, threshold=0.5
# Bootstrap 5/30: logistic_lead24_Task2_sci_dft4_0.5.pth, threshold=0.5
# Bootstrap 6/30: logistic_lead24_Task2_sci_dft5_0.5.pth, threshold=0.5
# Bootstrap 7/30: logistic_lead24_Task2_sci_dft6_0.5.pth, threshold=0.5
# Bootstrap 8/30: logistic_lead24_Task2_sci_dft7_0.5.pth, threshold=0.5
# Bootstrap 9/30: logistic_lead24_Task2_sci_dft8_0.5.pth, threshold=0.5
# Bootstrap 10/30: logistic_lead24_Task2_sci_dft9_0.5.pth, threshold=0.5
# Bootstrap 11/30: logistic_lead24_Task2_sci_dft10_0.5.pth, threshold=0.5
# Bootstrap 12/30: logistic_lead24_Task2_sci_dft11_0.5.pth, threshold=0.5
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead24_Task1_opr_dft",
    sample_obj=lead24_opr_dft,
    model_dir="./Logreg_models/Task1_opr_dft_models",
    purpose="Task1",
    results_filename="Task1_raw_metrics_Logreg-O-DEF-24.csv",
)
# Out:
# Threshold: 0.470[0.470,0.470]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 140, Negative: 2236
# Bootstrap 1/30: logistic_lead24_Task1_opr_dft0_0.47.pth, threshold=0.47
# Bootstrap 2/30: logistic_lead24_Task1_opr_dft1_0.47.pth, threshold=0.47
# Bootstrap 3/30: logistic_lead24_Task1_opr_dft2_0.47.pth, threshold=0.47
# Bootstrap 4/30: logistic_lead24_Task1_opr_dft3_0.47.pth, threshold=0.47
# Bootstrap 5/30: logistic_lead24_Task1_opr_dft4_0.47.pth, threshold=0.47
# Bootstrap 6/30: logistic_lead24_Task1_opr_dft5_0.47.pth, threshold=0.47
# Bootstrap 7/30: logistic_lead24_Task1_opr_dft6_0.47.pth, threshold=0.47
# Bootstrap 8/30: logistic_lead24_Task1_opr_dft7_0.47.pth, threshold=0.47
# Bootstrap 9/30: logistic_lead24_Task1_opr_dft8_0.47.pth, threshold=0.47
# Bootstrap 10/30: logistic_lead24_Task1_opr_dft9_0.47.pth, threshold=0.47
# Bootstrap 11/30: logistic_lead24_Task1_opr_dft10_0.47.pth, threshold=0.47
# ...

# %%
period_results = GenMetrics_logreg(
    model_name="logistic_lead24_Task2_opr_dft",
    sample_obj=lead24_opr_dft,
    model_dir="./Logreg_models/Task2_opr_dft_models",
    purpose="Task2",
    results_filename="Task2_raw_metrics_Logreg-O-DEF-24.csv",
)
# Out:
# Threshold: 0.460[0.460,0.460]
#
# Testing period 1/3: 2020-01-01 to 2022-01-01
# Positive: 140, Negative: 3422
# Bootstrap 1/30: logistic_lead24_Task2_opr_dft0_0.46.pth, threshold=0.46
# Bootstrap 2/30: logistic_lead24_Task2_opr_dft1_0.46.pth, threshold=0.46
# Bootstrap 3/30: logistic_lead24_Task2_opr_dft2_0.46.pth, threshold=0.46
# Bootstrap 4/30: logistic_lead24_Task2_opr_dft3_0.46.pth, threshold=0.46
# Bootstrap 5/30: logistic_lead24_Task2_opr_dft4_0.46.pth, threshold=0.46
# Bootstrap 6/30: logistic_lead24_Task2_opr_dft5_0.46.pth, threshold=0.46
# Bootstrap 7/30: logistic_lead24_Task2_opr_dft6_0.46.pth, threshold=0.46
# Bootstrap 8/30: logistic_lead24_Task2_opr_dft7_0.46.pth, threshold=0.46
# Bootstrap 9/30: logistic_lead24_Task2_opr_dft8_0.46.pth, threshold=0.46
# Bootstrap 10/30: logistic_lead24_Task2_opr_dft9_0.46.pth, threshold=0.46
# Bootstrap 11/30: logistic_lead24_Task2_opr_dft10_0.46.pth, threshold=0.46
# ...
