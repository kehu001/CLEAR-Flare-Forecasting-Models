# %%
import numpy as np
import pandas as pd
import torch
import os
import matplotlib.pyplot as plt
# Out:
# d:\Program Files\anaconda3\envs\torch126\Lib\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
import sys

from flare_preprocessing import *
from utilities import *

# %%
# %load_ext autoreload
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
working_dir = 'D:/2024_S1/ML_SEP_2402/Final_update/Open_Repo'
opr = opr_data_preprocessing(working_dir + "/data/v2_ftp_flares_1997_2024.csv")
sci = sci_data_preprocessing(working_dir + "/data/Sci_matched_with_assigned_ar_20100101_20241231.csv", opr)
# Out:
# d:\2024_S1\ML_SEP_2402\Final_update\Open_Repo\2607Revision\utilities.py:64: RuntimeWarning: divide by zero encountered in log10
#   return np.log10(intensity * 10 ** -8)
# Shape of the operation data: (25364, 9)
# Shape of the science-quality data: (32675, 26)

# %% [markdown]
# # Samples

# %% [markdown]
# ## DFT sharps

# %%
from New_SampleConstruction import *

# %%
# read the parquet file
import fastparquet
high_qual_sharp = pd.read_parquet('D:\\0626_temp\\processed_high-qual_near-center-70_no-nas_flares.parquet', engine='fastparquet')

# %%
opr = opr[opr['peak_time'] < '2020-01-01']
sci = sci[sci['peak_time'] < '2020-01-01']
high_qual_sharp = high_qual_sharp[high_qual_sharp['T_REC'] < '2020-01-01']

# %%
nowcast_sci_dft = New_SampleConstruction()
nowcast_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=0)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
nowcast_opr_dft = New_SampleConstruction()
nowcast_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=0)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
lead6_sci_dft = New_SampleConstruction()
lead6_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=6)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
lead6_opr_dft = New_SampleConstruction()
lead6_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=6)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
lead12_sci_dft = New_SampleConstruction()
lead12_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=12)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
lead12_opr_dft = New_SampleConstruction()
lead12_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=12)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
lead24_sci_dft = New_SampleConstruction()
lead24_sci_dft.samples_from_harp(sci, high_qual_sharp, lead_window=24)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %%
lead24_opr_dft = New_SampleConstruction()
lead24_opr_dft.samples_from_harp(opr, high_qual_sharp, lead_window=24)
# Out:
# Processing HARPNUM: np.int64(1)
# Processing HARPNUM: np.int64(2)
# Processing HARPNUM: np.int64(5)
# Processing HARPNUM: np.int64(6)
# Processing HARPNUM: np.int64(8)
# Processing HARPNUM: np.int64(10)
# Processing HARPNUM: np.int64(11)
# Processing HARPNUM: np.int64(12)
# Processing HARPNUM: np.int64(14)
# Processing HARPNUM: np.int64(15)
# Processing HARPNUM: np.int64(16)
# Processing HARPNUM: np.int64(17)
# Processing HARPNUM: np.int64(19)
# Processing HARPNUM: np.int64(20)
# Processing HARPNUM: np.int64(23)
# Processing HARPNUM: np.int64(24)
# Processing HARPNUM: np.int64(25)
# Processing HARPNUM: np.int64(26)
# Processing HARPNUM: np.int64(29)
# Processing HARPNUM: np.int64(32)
# Processing HARPNUM: np.int64(35)
# Processing HARPNUM: np.int64(36)
# Processing HARPNUM: np.int64(37)
# Processing HARPNUM: np.int64(38)
# Processing HARPNUM: np.int64(39)
# Processing HARPNUM: np.int64(40)
# Processing HARPNUM: np.int64(41)
# Processing HARPNUM: np.int64(43)
# ...

# %% [markdown]
# # LSTM Models

# %%
from New_lstm2 import *

# %% [markdown]
# ## Task 1

# %%
nowcast_Task1_sci_dft = train_lstm()
nowcast_Task1_sci_dft.train(nowcast_sci_dft.inputs_profile, nowcast_sci_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 4013 positives and 6424 negatives.
# BCE positive-class weight: 1.6008
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.6489906877647211
# Epoch 2, avg loss: 0.4222508768240611
# Epoch 3, avg loss: 0.35605026560801045
# Epoch 4, avg loss: 0.3242892845545286
# Epoch 5, avg loss: 0.2976594622488375
# Epoch 6, avg loss: 0.28889061804906824
# Epoch 7, avg loss: 0.2708408405751358
# Epoch 8, avg loss: 0.25479120788750825
# Epoch 9, avg loss: 0.2483558969365226
# Epoch 10, avg loss: 0.2581472409728133
# Epoch 11, avg loss: 0.23938202876367687
# Epoch 12, avg loss: 0.2255768409849685
# Epoch 13, avg loss: 0.22517373725587939
# Epoch 14, avg loss: 0.22626554055346382
# Epoch 15, avg loss: 0.21078349852267605
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.6393119354306915
# Epoch 2, avg loss: 0.3936814345695354
# Epoch 3, avg loss: 0.3502474085048393
# Epoch 4, avg loss: 0.3186087284559085
# Epoch 5, avg loss: 0.30739861597985396
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_sci_dft_models"

for i, model in enumerate(nowcast_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"nowcast_Task1_sci_dft{i}_{np.mean(nowcast_Task1_sci_dft.thresholds)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
nowcast_Task1_opr_dft = train_lstm()
nowcast_Task1_opr_dft.train(nowcast_opr_dft.inputs_profile, nowcast_opr_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 2984 positives and 8540 negatives.
# BCE positive-class weight: 2.8619
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.7580206596189075
# Epoch 2, avg loss: 0.44908908440007106
# Epoch 3, avg loss: 0.3882425536712011
# Epoch 4, avg loss: 0.3581656159626113
# Epoch 5, avg loss: 0.33268845826387405
# Epoch 6, avg loss: 0.32293911278247833
# Epoch 7, avg loss: 0.31842213852538004
# Epoch 8, avg loss: 0.2965699839923117
# Epoch 9, avg loss: 0.2767348246441947
# Epoch 10, avg loss: 0.27944978061649534
# Epoch 11, avg loss: 0.2559291155801879
# Epoch 12, avg loss: 0.25103754558497005
# Epoch 13, avg loss: 0.23812621641490195
# Epoch 14, avg loss: 0.2356067765918043
# Epoch 15, avg loss: 0.20759826377034188
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7350811994738049
# Epoch 2, avg loss: 0.459560360511144
# Epoch 3, avg loss: 0.4003161625729667
# Epoch 4, avg loss: 0.3639414492580626
# Epoch 5, avg loss: 0.340354198217392
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_opr_dft_models"

for i, model in enumerate(nowcast_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"nowcast_Task1_opr_dft{i}_{np.round(np.mean(nowcast_Task1_opr_dft.thresholds),2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead6_Task1_sci_dft = train_lstm()
lead6_Task1_sci_dft.train(lead6_sci_dft.inputs_profile, lead6_sci_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 3989 positives and 6359 negatives.
# BCE positive-class weight: 1.5941
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.6486472748219967
# Epoch 2, avg loss: 0.4231179390102625
# Epoch 3, avg loss: 0.3719145342707634
# Epoch 4, avg loss: 0.34670380782335997
# Epoch 5, avg loss: 0.3278390968218446
# Epoch 6, avg loss: 0.31794020999222994
# Epoch 7, avg loss: 0.303893905878067
# Epoch 8, avg loss: 0.28066850639879704
# Epoch 9, avg loss: 0.27071646209806205
# Epoch 10, avg loss: 0.26932708341628314
# Epoch 11, avg loss: 0.2727582862600684
# Epoch 12, avg loss: 0.2775797452777624
# Epoch 13, avg loss: 0.24984889244660735
# Epoch 14, avg loss: 0.23891423782333732
# Epoch 15, avg loss: 0.24447069074958563
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.6312825612723827
# Epoch 2, avg loss: 0.41264232285320757
# Epoch 3, avg loss: 0.3765943631529808
# Epoch 4, avg loss: 0.3500582780689001
# Epoch 5, avg loss: 0.3337747871875763
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_sci_dft_models"

for i, model in enumerate(lead6_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead6_Task1_sci_dft{i}_{np.mean(lead6_Task1_sci_dft.thresholds)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead6_Task1_opr_dft = train_lstm()
lead6_Task1_opr_dft.train(lead6_opr_dft.inputs_profile, lead6_opr_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 2971 positives and 8430 negatives.
# BCE positive-class weight: 2.8374
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.7589832534281056
# Epoch 2, avg loss: 0.48866349693094746
# Epoch 3, avg loss: 0.42194059524643285
# Epoch 4, avg loss: 0.39408174056685374
# Epoch 5, avg loss: 0.3695390855663278
# Epoch 6, avg loss: 0.3514426322130675
# Epoch 7, avg loss: 0.3262512799394265
# Epoch 8, avg loss: 0.3168047189377667
# Epoch 9, avg loss: 0.3044946776347214
# Epoch 10, avg loss: 0.2943930732232801
# Epoch 11, avg loss: 0.2838364697239372
# Epoch 12, avg loss: 0.27662275312991624
# Epoch 13, avg loss: 0.26409272991874244
# Epoch 14, avg loss: 0.2498691871427418
# Epoch 15, avg loss: 0.25690525686472987
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7504591586884488
# Epoch 2, avg loss: 0.4751170619150226
# Epoch 3, avg loss: 0.4167556089631627
# Epoch 4, avg loss: 0.38760802066058253
# Epoch 5, avg loss: 0.3580039418145512
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_opr_dft_models"

for i, model in enumerate(lead6_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead6_Task1_opr_dft{i}_{np.round(np.mean(lead6_Task1_opr_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead12_Task1_sci_dft = train_lstm()
lead12_Task1_sci_dft.train(lead12_sci_dft.inputs_profile, lead12_sci_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 3951 positives and 6296 negatives.
# BCE positive-class weight: 1.5935
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.6067744038999081
# Epoch 2, avg loss: 0.4290544133633375
# Epoch 3, avg loss: 0.3909741960465908
# Epoch 4, avg loss: 0.3636980954557657
# Epoch 5, avg loss: 0.34436370320618154
# Epoch 6, avg loss: 0.3329282458871603
# Epoch 7, avg loss: 0.33420522715896367
# Epoch 8, avg loss: 0.3212258696556091
# Epoch 9, avg loss: 0.3109529150649905
# Epoch 10, avg loss: 0.29069713205099107
# Epoch 11, avg loss: 0.29764166232198475
# Epoch 12, avg loss: 0.28151447530835866
# Epoch 13, avg loss: 0.2696540541946888
# Epoch 14, avg loss: 0.2591945268213749
# Epoch 15, avg loss: 0.3108763214200735
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.6757019191980362
# Epoch 2, avg loss: 0.46172351501882075
# Epoch 3, avg loss: 0.4073498476296663
# Epoch 4, avg loss: 0.38293198868632317
# Epoch 5, avg loss: 0.3651655688881874
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_sci_dft_models"

for i, model in enumerate(lead12_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead12_Task1_sci_dft{i}_{np.round(np.mean(lead12_Task1_sci_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead12_Task1_opr_dft = train_lstm()
lead12_Task1_opr_dft.train(lead12_opr_dft.inputs_profile, lead12_opr_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 2940 positives and 8285 negatives.
# BCE positive-class weight: 2.8180
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.783596096710227
# Epoch 2, avg loss: 0.5204014603433937
# Epoch 3, avg loss: 0.4536625914190007
# Epoch 4, avg loss: 0.4168492028082924
# Epoch 5, avg loss: 0.39068809391438275
# Epoch 6, avg loss: 0.37775515773515594
# Epoch 7, avg loss: 0.3545579053889746
# Epoch 8, avg loss: 0.3390174665670285
# Epoch 9, avg loss: 0.3176460033175589
# Epoch 10, avg loss: 0.3603626535884265
# Epoch 11, avg loss: 0.3819519253982895
# Epoch 12, avg loss: 0.3490619308304513
# Epoch 13, avg loss: 0.3207843993929611
# Epoch 14, avg loss: 0.30709645323369694
# Epoch 15, avg loss: 0.2880706912142107
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7521033249367243
# Epoch 2, avg loss: 0.5169215185203772
# Epoch 3, avg loss: 0.45610126955755825
# Epoch 4, avg loss: 0.43029803962543095
# Epoch 5, avg loss: 0.414698520268517
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_opr_dft_models"

for i, model in enumerate(lead12_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead12_Task1_opr_dft{i}_{np.mean(lead12_Task1_opr_dft.thresholds)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead24_Task1_sci_dft = train_lstm()
lead24_Task1_sci_dft.train(lead24_sci_dft.inputs_profile, lead24_sci_dft.labels, "Task1", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 3867 positives and 6071 negatives.
# BCE positive-class weight: 1.5700
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.620405488587045
# Epoch 2, avg loss: 0.4370758281899737
# Epoch 3, avg loss: 0.4260755730913831
# Epoch 4, avg loss: 0.4150626612948133
# Epoch 5, avg loss: 0.3943656243674167
# Epoch 6, avg loss: 0.38442845294227845
# Epoch 7, avg loss: 0.3582933370943193
# Epoch 8, avg loss: 0.3573355686354947
# Epoch 9, avg loss: 0.34642744180444
# Epoch 10, avg loss: 0.33301542331646017
# Epoch 11, avg loss: 0.32465375456717105
# Epoch 12, avg loss: 0.3123180196656809
# Epoch 13, avg loss: 0.30853986430477787
# Epoch 14, avg loss: 0.2900309854900682
# Epoch 15, avg loss: 0.32964278815628645
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.674291167166326
# Epoch 2, avg loss: 0.48043847742018764
# Epoch 3, avg loss: 0.4425738643516194
# Epoch 4, avg loss: 0.4229477763950051
# Epoch 5, avg loss: 0.40868079971957516
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_sci_dft_models"

for i, model in enumerate(lead24_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead24_Task1_sci_dft{i}_{np.mean(lead24_Task1_sci_dft.thresholds)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead24_Task1_opr_dft = train_lstm()
lead24_Task1_opr_dft.train(lead24_opr_dft.inputs_profile, lead24_opr_dft.labels, "Task1",
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using all training samples: 2889 positives and 7916 negatives.
# BCE positive-class weight: 2.7400
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.7893573067017964
# Epoch 2, avg loss: 0.5819450552974429
# Epoch 3, avg loss: 0.5285866814000266
# Epoch 4, avg loss: 0.49794265450466246
# Epoch 5, avg loss: 0.48607003121148973
# Epoch 6, avg loss: 0.45302935618729817
# Epoch 7, avg loss: 0.4372016893965857
# Epoch 8, avg loss: 0.4540238532991636
# Epoch 9, avg loss: 0.4222799844685055
# Epoch 10, avg loss: 0.41795438669976737
# Epoch 11, avg loss: 0.43736899324825834
# Epoch 12, avg loss: 0.41974843062815215
# Epoch 13, avg loss: 0.39712272655396236
# Epoch 14, avg loss: 0.3946708162270841
# Epoch 15, avg loss: 0.38415980693839846
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7973143841539111
# Epoch 2, avg loss: 0.5778881801026208
# Epoch 3, avg loss: 0.5187905214372135
# Epoch 4, avg loss: 0.4837351313659123
# Epoch 5, avg loss: 0.46862598650512244
# ...

# %%
save_dir = ".\\LSTM_models\\Task1_opr_dft_models"

for i, model in enumerate(lead24_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead24_Task1_opr_dft{i}_{np.mean(lead24_Task1_opr_dft.thresholds)}.pth")
    torch.save(model.state_dict(), model_path)

# %% [markdown]
# ## Task2

# %%
nowcast_Task2_sci_dft = train_lstm(pos_weight=2.0)
nowcast_Task2_sci_dft.train(nowcast_sci_dft.inputs_profile, nowcast_sci_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 4013 positives and 8026 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.7809254622205775
# Epoch 2, avg loss: 0.6597901310058351
# Epoch 3, avg loss: 0.6301117342837314
# Epoch 4, avg loss: 0.6126315986856501
# Epoch 5, avg loss: 0.5873300626556924
# Epoch 6, avg loss: 0.5745228002680108
# Epoch 7, avg loss: 0.5570531880601923
# Epoch 8, avg loss: 0.5449938298539913
# Epoch 9, avg loss: 0.5353888349330171
# Epoch 10, avg loss: 0.5310810928014998
# Epoch 11, avg loss: 0.5196342553864134
# Epoch 12, avg loss: 0.49733778802638356
# Epoch 13, avg loss: 0.5452506979729267
# Epoch 14, avg loss: 0.5175685670147551
# Epoch 15, avg loss: 0.4972312631125146
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7768375626269807
# Epoch 2, avg loss: 0.6512807525218801
# Epoch 3, avg loss: 0.6219830183272667
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_sci_dft_models"

for i, model in enumerate(nowcast_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"nowcast_Task2_sci_dft{i}_{np.round(np.mean(nowcast_Task2_sci_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
nowcast_Task2_opr_dft = train_lstm(pos_weight=2.0)
nowcast_Task2_opr_dft.train(nowcast_opr_dft.inputs_profile, nowcast_opr_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 2984 positives and 5968 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.8008543857629749
# Epoch 2, avg loss: 0.6375221743963767
# Epoch 3, avg loss: 0.5966251673905746
# Epoch 4, avg loss: 0.5748644583467124
# Epoch 5, avg loss: 0.5502783863440804
# Epoch 6, avg loss: 0.535147561111312
# Epoch 7, avg loss: 0.52281821033229
# Epoch 8, avg loss: 0.5034010850864908
# Epoch 9, avg loss: 0.4962708043015521
# Epoch 10, avg loss: 0.49517608077629754
# Epoch 11, avg loss: 0.47272037768709485
# Epoch 12, avg loss: 0.4607904657073643
# Epoch 13, avg loss: 0.4526532098003056
# Epoch 14, avg loss: 0.4528642875560816
# Epoch 15, avg loss: 0.4406547066958054
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7920735115590303
# Epoch 2, avg loss: 0.6142119817111803
# Epoch 3, avg loss: 0.5741721771765447
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_opr_dft_models"

for i, model in enumerate(nowcast_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"nowcast_Task2_opr_dft{i}_{np.round(np.mean(nowcast_Task2_opr_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead6_Task2_sci_dft = train_lstm(pos_weight=2.0)
lead6_Task2_sci_dft.train(lead6_sci_dft.inputs_profile, lead6_sci_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=15)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 3989 positives and 7978 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.7756926968533505
# Epoch 2, avg loss: 0.6669148982212108
# Epoch 3, avg loss: 0.6402583157503476
# Epoch 4, avg loss: 0.6249899143172849
# Epoch 5, avg loss: 0.6044947485769948
# Epoch 6, avg loss: 0.5782200104446822
# Epoch 7, avg loss: 0.5680711394356143
# Epoch 8, avg loss: 0.562073665600951
# Epoch 9, avg loss: 0.541572795439792
# Epoch 10, avg loss: 0.5407316492449853
# Epoch 11, avg loss: 0.5249490414255409
# Epoch 12, avg loss: 0.5045671453399043
# Epoch 13, avg loss: 0.5013430756266399
# Epoch 14, avg loss: 0.5043313022582762
# Epoch 15, avg loss: 0.4981571557701275
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7844305435816447
# Epoch 2, avg loss: 0.6637519867189469
# Epoch 3, avg loss: 0.6396236163313671
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_sci_dft_models"

for i, model in enumerate(lead6_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead6_Task2_sci_dft{i}_{np.round(np.mean(lead6_Task2_sci_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead6_Task2_opr_dft = train_lstm(pos_weight=2.0)
lead6_Task2_opr_dft.train(lead6_opr_dft.inputs_profile, lead6_opr_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=12)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 2971 positives and 5942 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.8169432766195657
# Epoch 2, avg loss: 0.653460100941036
# Epoch 3, avg loss: 0.6139690547749617
# Epoch 4, avg loss: 0.5900628126185873
# Epoch 5, avg loss: 0.5761570273966029
# Epoch 6, avg loss: 0.5542671399703925
# Epoch 7, avg loss: 0.5381291150182917
# Epoch 8, avg loss: 0.5318904925083768
# Epoch 9, avg loss: 0.5391254662603572
# Epoch 10, avg loss: 0.5110948608405348
# Epoch 11, avg loss: 0.5033922700778298
# Epoch 12, avg loss: 0.49018607839294104
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.8045844763949297
# Epoch 2, avg loss: 0.6430331537688988
# Epoch 3, avg loss: 0.6075749310894288
# Epoch 4, avg loss: 0.5819354212802389
# Epoch 5, avg loss: 0.5653887784135514
# Epoch 6, avg loss: 0.5560475998166678
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_opr_dft_models"

for i, model in enumerate(lead6_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead6_Task2_opr_dft{i}_{np.round(np.mean(lead6_Task2_opr_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead12_Task2_sci_dft = train_lstm(pos_weight=2.0)
lead12_Task2_sci_dft.train(lead12_sci_dft.inputs_profile, lead12_sci_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=12)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 3951 positives and 7902 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.7898540503304937
# Epoch 2, avg loss: 0.66837654100812
# Epoch 3, avg loss: 0.6427245690770771
# Epoch 4, avg loss: 0.6273093547510065
# Epoch 5, avg loss: 0.6159655050091122
# Epoch 6, avg loss: 0.6030586821877438
# Epoch 7, avg loss: 0.587539685809094
# Epoch 8, avg loss: 0.5918363578941511
# Epoch 9, avg loss: 0.6113076537199642
# Epoch 10, avg loss: 0.6039247431832812
# Epoch 11, avg loss: 0.5840839270664298
# Epoch 12, avg loss: 0.6077536431991536
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7903614685587261
# Epoch 2, avg loss: 0.698043097620425
# Epoch 3, avg loss: 0.6723868360985881
# Epoch 4, avg loss: 0.6506291349296984
# Epoch 5, avg loss: 0.6377479129511378
# Epoch 6, avg loss: 0.6211801974669747
# Epoch 7, avg loss: 0.6063072266785995
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_sci_dft_models"

for i, model in enumerate(lead12_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead12_Task2_sci_dft{i}_{np.round(np.mean(lead12_Task2_sci_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead12_Task2_opr_dft = train_lstm(pos_weight=2.0)
lead12_Task2_opr_dft.train(lead12_opr_dft.inputs_profile, lead12_opr_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=12)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 2940 positives and 5880 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.8149041051373762
# Epoch 2, avg loss: 0.6474211198442122
# Epoch 3, avg loss: 0.6115808153853697
# Epoch 4, avg loss: 0.5974462961449343
# Epoch 5, avg loss: 0.5764823069467264
# Epoch 6, avg loss: 0.5631150186938398
# Epoch 7, avg loss: 0.5538399578893886
# Epoch 8, avg loss: 0.549056218827472
# Epoch 9, avg loss: 0.5367318974698291
# Epoch 10, avg loss: 0.5229868932681925
# Epoch 11, avg loss: 0.5074301007039407
# Epoch 12, avg loss: 0.49338989047443166
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.7979367270189173
# Epoch 2, avg loss: 0.6775619229849648
# Epoch 3, avg loss: 0.6424259937861386
# Epoch 4, avg loss: 0.6221083683126113
# Epoch 5, avg loss: 0.6003359858604038
# Epoch 6, avg loss: 0.583910782547558
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_opr_dft_models"

for i, model in enumerate(lead12_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead12_Task2_opr_dft{i}_{np.round(np.mean(lead12_Task2_opr_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead24_Task2_sci_dft = train_lstm(pos_weight=2.0)
lead24_Task2_sci_dft.train(lead24_sci_dft.inputs_profile, lead24_sci_dft.labels, "Task2", 
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=12)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 3867 positives and 7734 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.80712411403656
# Epoch 2, avg loss: 0.7132953060997858
# Epoch 3, avg loss: 0.6866384744644165
# Epoch 4, avg loss: 0.6704326940907372
# Epoch 5, avg loss: 0.6436757968531714
# Epoch 6, avg loss: 0.6375613487429089
# Epoch 7, avg loss: 0.6189451181226306
# Epoch 8, avg loss: 0.6046970423724917
# Epoch 9, avg loss: 0.6026448117362129
# Epoch 10, avg loss: 0.5853898170921538
# Epoch 11, avg loss: 0.5809002959065968
# Epoch 12, avg loss: 0.5784590201245414
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.8009325683116912
# Epoch 2, avg loss: 0.7085234721501669
# Epoch 3, avg loss: 0.6881510727935367
# Epoch 4, avg loss: 0.667216400967704
# Epoch 5, avg loss: 0.65230702691608
# Epoch 6, avg loss: 0.6369282503922781
# Epoch 7, avg loss: 0.626176052292188
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_sci_dft_models"

for i, model in enumerate(lead24_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead24_Task2_sci_dft{i}_{np.round(np.mean(lead24_Task2_sci_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %%
lead24_Task2_opr_dft = train_lstm(pos_weight=2.0)
lead24_Task2_opr_dft.train(lead24_opr_dft.inputs_profile, lead24_opr_dft.labels, "Task2",
                            pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'), n_epoch=12)
# Out:
# get samples
# Using negative undersampling with 2 negatives per positive.
# Each bootstrap will contain approximately 2889 positives and 5778 negatives.
# BCE positive-class weight: 2
# Bootstrap iteration 1/30
# Epoch 1, avg loss: 0.8262202926536104
# Epoch 2, avg loss: 0.7153601913309809
# Epoch 3, avg loss: 0.6852714081308735
# Epoch 4, avg loss: 0.6628536332899065
# Epoch 5, avg loss: 0.6417922137388542
# Epoch 6, avg loss: 0.6287256568225462
# Epoch 7, avg loss: 0.616819296310197
# Epoch 8, avg loss: 0.5971192766481371
# Epoch 9, avg loss: 0.5768611782522344
# Epoch 10, avg loss: 0.5615139545789406
# Epoch 11, avg loss: 0.5571397467335658
# Epoch 12, avg loss: 0.5568545064819392
# Bootstrap iteration 2/30
# Epoch 1, avg loss: 0.8468619682895604
# Epoch 2, avg loss: 0.7217451440754221
# Epoch 3, avg loss: 0.6773471992407272
# Epoch 4, avg loss: 0.6536918878555298
# Epoch 5, avg loss: 0.638336348889479
# Epoch 6, avg loss: 0.6170703670871791
# ...

# %%
save_dir = ".\\LSTM_models\\Task2_opr_dft_models"

for i, model in enumerate(lead24_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, f"lead24_Task2_opr_dft{i}_{np.round(np.mean(lead24_Task2_opr_dft.thresholds), 2)}.pth")
    torch.save(model.state_dict(), model_path)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Task1

# %%
from New_logistic import *
import joblib

# %%
logistic_nowcast_Task1_sci_dft = train_logistic()
logistic_nowcast_Task1_sci_dft.train_logistic(nowcast_sci_dft.inputs_profile, nowcast_sci_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 4013 positives and 6424 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 2/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 3/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 4/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 5/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 6/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 7/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 8/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 9/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# Bootstrap iteration 10/30
# Bootstrap sample: 4013 positives, 6424 negatives; ratio=1.6008
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_sci_dft_models"

for i, model in enumerate(logistic_nowcast_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_nowcast_Task1_sci_dft{i}_{np.round(np.mean(logistic_nowcast_Task1_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_nowcast_Task1_opr_dft = train_logistic()
logistic_nowcast_Task1_opr_dft.train_logistic(nowcast_opr_dft.inputs_profile, nowcast_opr_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 2984 positives and 8540 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 2/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 3/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 4/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 5/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 6/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 7/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 8/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 9/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# Bootstrap iteration 10/30
# Bootstrap sample: 2984 positives, 8540 negatives; ratio=2.8619
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_opr_dft_models"

for i, model in enumerate(logistic_nowcast_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_nowcast_Task1_opr_dft{i}_{np.round(np.mean(logistic_nowcast_Task1_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead6_Task1_sci_dft = train_logistic()
logistic_lead6_Task1_sci_dft.train_logistic(lead6_sci_dft.inputs_profile, lead6_sci_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 3989 positives and 6359 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 2/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 3/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 4/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 5/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 6/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 7/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 8/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 9/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# Bootstrap iteration 10/30
# Bootstrap sample: 3989 positives, 6359 negatives; ratio=1.5941
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_sci_dft_models"

for i, model in enumerate(logistic_lead6_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead6_Task1_sci_dft{i}_{np.round(np.mean(logistic_lead6_Task1_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead6_Task1_opr_dft = train_logistic()
logistic_lead6_Task1_opr_dft.train_logistic(lead6_opr_dft.inputs_profile, lead6_opr_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 2971 positives and 8430 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 2/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 3/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 4/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 5/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 6/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 7/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 8/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 9/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# Bootstrap iteration 10/30
# Bootstrap sample: 2971 positives, 8430 negatives; ratio=2.8374
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_opr_dft_models"

for i, model in enumerate(logistic_lead6_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead6_Task1_opr_dft{i}_{np.round(np.mean(logistic_lead6_Task1_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead12_Task1_sci_dft = train_logistic()
logistic_lead12_Task1_sci_dft.train_logistic(lead12_sci_dft.inputs_profile, lead12_sci_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 3951 positives and 6296 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 2/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 3/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 4/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 5/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 6/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 7/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 8/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 9/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# Bootstrap iteration 10/30
# Bootstrap sample: 3951 positives, 6296 negatives; ratio=1.5935
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_sci_dft_models"

for i, model in enumerate(logistic_lead12_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead12_Task1_sci_dft{i}_{np.round(np.mean(logistic_lead12_Task1_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead12_Task1_opr_dft = train_logistic()
logistic_lead12_Task1_opr_dft.train_logistic(lead12_opr_dft.inputs_profile, lead12_opr_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 2940 positives and 8285 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 2/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 3/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 4/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 5/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 6/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 7/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 8/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 9/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# Bootstrap iteration 10/30
# Bootstrap sample: 2940 positives, 8285 negatives; ratio=2.8180
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_opr_dft_models"

for i, model in enumerate(logistic_lead12_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead12_Task1_opr_dft{i}_{np.round(np.mean(logistic_lead12_Task1_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead24_Task1_sci_dft = train_logistic()
logistic_lead24_Task1_sci_dft.train_logistic(lead24_sci_dft.inputs_profile, lead24_sci_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 3867 positives and 6071 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 2/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 3/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 4/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 5/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 6/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 7/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 8/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 9/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# Bootstrap iteration 10/30
# Bootstrap sample: 3867 positives, 6071 negatives; ratio=1.5700
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_sci_dft_models"

for i, model in enumerate(logistic_lead24_Task1_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead24_Task1_sci_dft{i}_{np.round(np.mean(logistic_lead24_Task1_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead24_Task1_opr_dft = train_logistic()
logistic_lead24_Task1_opr_dft.train_logistic(lead24_opr_dft.inputs_profile, lead24_opr_dft.labels, "Task1", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using all training samples: 2889 positives and 7916 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 2/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 3/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 4/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 5/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 6/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 7/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 8/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 9/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# Bootstrap iteration 10/30
# Bootstrap sample: 2889 positives, 7916 negatives; ratio=2.7400
# ...

# %%
save_dir = ".\\Logreg_models\\Task1_opr_dft_models"

for i, model in enumerate(logistic_lead24_Task1_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead24_Task1_opr_dft{i}_{np.round(np.mean(logistic_lead24_Task1_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %% [markdown]
# ### Task2

# %%
from New_logistic import *
import joblib

# %%
logistic_nowcast_Task2_sci_dft = train_logistic(pos_weight=2.0)
logistic_nowcast_Task2_sci_dft.train_logistic(nowcast_sci_dft.inputs_profile, nowcast_sci_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 4013 positives and 8026 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 4013 positives, 8026 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_sci_dft_models"

for i, model in enumerate(logistic_nowcast_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_nowcast_Task2_sci_dft{i}_{np.round(np.mean(logistic_nowcast_Task2_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_nowcast_Task2_opr_dft = train_logistic(pos_weight=2.0)
logistic_nowcast_Task2_opr_dft.train_logistic(nowcast_opr_dft.inputs_profile, nowcast_opr_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 2984 positives and 5968 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 2984 positives, 5968 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_opr_dft_models"

for i, model in enumerate(logistic_nowcast_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_nowcast_Task2_opr_dft{i}_{np.round(np.mean(logistic_nowcast_Task2_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead6_Task2_sci_dft = train_logistic(pos_weight=2.0)
logistic_lead6_Task2_sci_dft.train_logistic(lead6_sci_dft.inputs_profile, lead6_sci_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 3989 positives and 7978 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 3989 positives, 7978 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_sci_dft_models"

for i, model in enumerate(logistic_lead6_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead6_Task2_sci_dft{i}_{np.round(np.mean(logistic_lead6_Task2_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead6_Task2_opr_dft = train_logistic(pos_weight=2.0)
logistic_lead6_Task2_opr_dft.train_logistic(lead6_opr_dft.inputs_profile, lead6_opr_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 2971 positives and 5942 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 2971 positives, 5942 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_opr_dft_models"

for i, model in enumerate(logistic_lead6_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead6_Task2_opr_dft{i}_{np.round(np.mean(logistic_lead6_Task2_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead12_Task2_sci_dft = train_logistic(pos_weight=2.0)
logistic_lead12_Task2_sci_dft.train_logistic(lead12_sci_dft.inputs_profile, lead12_sci_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 3951 positives and 7902 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 3951 positives, 7902 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_sci_dft_models"

for i, model in enumerate(logistic_lead12_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead12_Task2_sci_dft{i}_{np.round(np.mean(logistic_lead12_Task2_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead12_Task2_opr_dft = train_logistic(pos_weight=2.0)
logistic_lead12_Task2_opr_dft.train_logistic(lead12_opr_dft.inputs_profile, lead12_opr_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 2940 positives and 5880 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 2940 positives, 5880 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_opr_dft_models"

for i, model in enumerate(logistic_lead12_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead12_Task2_opr_dft{i}_{np.round(np.mean(logistic_lead12_Task2_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead24_Task2_sci_dft = train_logistic(pos_weight=2.0)
logistic_lead24_Task2_sci_dft.train_logistic(lead24_sci_dft.inputs_profile, lead24_sci_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 3867 positives and 7734 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 3867 positives, 7734 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_sci_dft_models"

for i, model in enumerate(logistic_lead24_Task2_sci_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead24_Task2_sci_dft{i}_{np.round(np.mean(logistic_lead24_Task2_sci_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)

# %%
logistic_lead24_Task2_opr_dft = train_logistic(pos_weight=2.0)
logistic_lead24_Task2_opr_dft.train_logistic(lead24_opr_dft.inputs_profile, lead24_opr_dft.labels, "Task2", pd.to_datetime('2010-01-01'), pd.to_datetime('2020-01-01'))
# Out:
# Using negative sampling with 2 negatives per positive.
# Each bootstrap will use 2889 positives and 5778 negatives.
# Bootstrap iteration 1/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 2/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 3/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 4/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 5/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 6/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 7/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 8/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 9/30
# Bootstrap sample: 2889 positives, 5778 negatives; ratio=2.0000
# Bootstrap iteration 10/30
# ...

# %%
save_dir = ".\\Logreg_models\\Task2_opr_dft_models"

for i, model in enumerate(logistic_lead24_Task2_opr_dft.models):
    os.makedirs(save_dir, exist_ok=True)
    model_path = os.path.join(save_dir, 
                              f"logistic_lead24_Task2_opr_dft{i}_{np.round(np.mean(logistic_lead24_Task2_opr_dft.thresholds),2)}.pth")
    joblib.dump(model, model_path)
