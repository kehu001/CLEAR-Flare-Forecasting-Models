# %%
from model_metric_comparison import plot_metric_difference_comparison

# %% [markdown]
# ## Response

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="O",
    predictor1="DEF", predictor2="DEF",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_DEF_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="O",
    predictor1="DEF", predictor2="DEF",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_DEF_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="O",
    predictor1="NRT", predictor2="NRT",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_NRT_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="O",
    predictor1="NRT", predictor2="NRT",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_NRT_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="O",
    predictor1="DEF", predictor2="DEF",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_logreg_DEF_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="O",
    predictor1="DEF", predictor2="DEF",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_logreg_DEF_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="O",
    predictor1="NRT", predictor2="NRT",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_logreg_NRT_S_vs_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="O",
    predictor1="NRT", predictor2="NRT",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_logreg_NRT_S_vs_O.pdf",
)

# %%
5393 / 0.008
# Out:
# 674125.0

# %% [markdown]
# ## Predictors

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="S",
    predictor1="DEF", predictor2="NRT",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_S_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="S",
    predictor1="DEF", predictor2="NRT",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_S_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="O", response2="O",
    predictor1="DEF", predictor2="NRT",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_O_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="O", response2="O",
    predictor1="DEF", predictor2="NRT",
    model1="LSTM", model2="LSTM",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_O_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="S",
    predictor1="DEF", predictor2="NRT",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_logreg_S_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="S",
    predictor1="DEF", predictor2="NRT",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_logreg_S_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="O", response2="O",
    predictor1="DEF", predictor2="NRT",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_logreg_O_DEF_vs_NRT.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="O", response2="O",
    predictor1="DEF", predictor2="NRT",
    model1="Logreg", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_logreg_O_DEF_vs_NRT.pdf",
)

# %% [markdown]
# ## Models

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="S",
    predictor1="DEF", predictor2="DEF",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_vs_logreg_DEF_S.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="S", response2="S",
    predictor1="NRT", predictor2="NRT",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_vs_logreg_NRT_S.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="O", response2="O",
    predictor1="DEF", predictor2="DEF",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_vs_logreg_DEF_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task1",
    response1="O", response2="O",
    predictor1="NRT", predictor2="NRT",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task1_lstm_vs_logreg_NRT_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="S",
    predictor1="DEF", predictor2="DEF",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_vs_logreg_DEF_S.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="S", response2="S",
    predictor1="NRT", predictor2="NRT",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_vs_logreg_NRT_S.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="O", response2="O",
    predictor1="DEF", predictor2="DEF",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_vs_logreg_DEF_O.pdf",
)

# %%
fig, differences = plot_metric_difference_comparison(
    results_dir="results",
    task="Task2",
    response1="O", response2="O",
    predictor1="NRT", predictor2="NRT",
    model1="LSTM", model2="Logreg",
    metric1="TSS", metric2="F1",
    output_path="figure/task2_lstm_vs_logreg_NRT_O.pdf",
)
